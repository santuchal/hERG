# %%
import os
import sys
import csv
import pickle
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from keras.regularizers import l2

# %%
df = pd.read_csv("../data/train_validation_cardio_tox_data.csv")
total_activity = df.loc[:,'ACTIVITY']
total_smiles = df.loc[:,'smiles']
X = pd.read_csv("../data/DESC_data/train_validation_cardio_tox_data_extract_features.csv")
x_label = list(X.columns)
y = total_activity
print("Total Row: ",df.shape[0])
print("Total Column: ", df.shape[1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=0)

model = Sequential()
model.add(Dense(2000, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.0001), input_shape=(1826,), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1000, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.0001), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(200, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X_train, y_train, epochs=1, batch_size=10)
# _, accuracy = model.evaluate(X, y)
# print('Accuracy: %.2f' % (accuracy*100))
# model.summary()

checkpoint_path = "../saved_model/desc_model_train/ckpt_file/trained_cardio_tox_fingerprint_model.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)
X = np.array(X)

model.fit(X_train, 
          y_train,  
          epochs=30,
          validation_data=(X_test, y_test),
          callbacks=[cp_callback])

model.save('../saved_model/desc_model_train/whole_model/cardio_tox_fingerprint_model')
# Out:
# /var/folders/x6/r97phsxs5qb8n7m2m39tbx0m0000gn/T/ipykernel_3144/442742908.py:1: DtypeWarning: Columns (118,119,120,124,125,126,130,131,132,136,137,138,142,143,144,148,149,150,154,155,156,160,161,162,166,167,168,172,173,174,268,269,270,274,275,276,280,281,282,286,287,288,292,293,294,298,299,300,304,305,306,310,311,312,316,317,318,322,323,324,327,328,329,332,333,334,337,338,339,342,343,344,347,348,349,352,353,354,357,358,359,362,363,364,367,368,369,372,373,374,377,378,379,382,383,384,387,388,389,392,393,394,397,398,399,402,403,404,407,408,409,412,413,414,417,418,419,422,423,424,480,481,482,483,493,494,495,496,720) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/train_validation_cardio_tox_data.csv")
# Total Row:  12620
# Total Column:  997
# 2023-02-21 13:56:28.952526: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-21 13:56:29.678341: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 375/375 [==============================] - 16s 41ms/step - loss: 3396851.2500 - accuracy: 0.5082 - val_loss: 209271.7656 - val_accuracy: 0.5293
#
# Epoch 00001: saving model to ../saved_model/desc_model_train/ckpt_file/trained_cardio_tox_fingerprint_model.ckpt
# 2023-02-21 13:56:46.385820: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ../saved_model/desc_model_train/whole_model/cardio_tox_fingerprint_model/assets

# %%
new_model = tf.keras.models.load_model('../saved_model/desc_model_train/whole_model/cardio_tox_fingerprint_model')
new_model.summary()
X_test_data = pd.read_csv('../data/DESC_data/external_test_set_pos_extract_features.csv')
acc = new_model.predict(X_test_data, verbose=2)
for accuracy in acc:
    print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 2000)              3654000
# _________________________________________________________________
# dropout (Dropout)            (None, 2000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              2001000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               200200
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 5,855,401
# Trainable params: 5,855,401
# Non-trainable params: 0
# _________________________________________________________________
# 2/2 - 0s
# Accuracy: 49.15
# Accuracy: 51.15
# Accuracy: 36.08
# Accuracy: 43.03
# Accuracy: 49.16
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 40.14
# Accuracy: 49.62
# Accuracy: 49.37
# Accuracy: 49.62
# Accuracy: 49.34
# Accuracy: 56.92
# Accuracy: 47.99
# Accuracy: 43.11
# Accuracy: 45.81
# Accuracy: 49.62
# Accuracy: 54.47
# Accuracy: 49.92
# Accuracy: 50.77
# Accuracy: 54.58
# Accuracy: 49.07
# Accuracy: 48.10
# Accuracy: 45.40
# Accuracy: 49.49
# Accuracy: 48.41
# Accuracy: 52.12
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 56.30
# Accuracy: 60.23
# Accuracy: 57.84
# Accuracy: 51.05
# Accuracy: 60.84
# Accuracy: 49.44
# Accuracy: 50.43
# Accuracy: 49.83
# Accuracy: 55.59
# Accuracy: 49.49
# Accuracy: 57.29
# Accuracy: 58.71
# Accuracy: 56.53

# %%
new_model = tf.keras.models.load_model('../saved_model/desc_model_train/whole_model/cardio_tox_fingerprint_model')
new_model.summary()
X_test_data = pd.read_csv('../data/DESC_data/external_test_set_neg_extract_features.csv')
acc = new_model.predict(X_test_data, verbose=2)
for accuracy in acc:
    print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 2000)              3654000
# _________________________________________________________________
# dropout (Dropout)            (None, 2000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              2001000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               200200
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 5,855,401
# Trainable params: 5,855,401
# Non-trainable params: 0
# _________________________________________________________________
# 2/2 - 0s
# Accuracy: 51.25
# Accuracy: 49.95
# Accuracy: 59.89
# Accuracy: 68.04
# Accuracy: 53.81
# Accuracy: 52.38
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 51.58
# Accuracy: 49.62
# Accuracy: 49.84
# Accuracy: 56.21
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 50.90
# Accuracy: 49.62
# Accuracy: 73.99
# Accuracy: 64.58
# Accuracy: 48.78
# Accuracy: 19.41
# Accuracy: 48.65
# Accuracy: 49.08
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 47.69
# Accuracy: 50.95
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 47.40
# Accuracy: 49.62
# Accuracy: 0.05
# Accuracy: 2.12
# Accuracy: 47.59
# Accuracy: 42.21
# Accuracy: 50.89
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 48.40
# Accuracy: 49.62
# Accuracy: 49.62

# %%
new_model = tf.keras.models.load_model('../saved_model/desc_model_train/whole_model/cardio_tox_fingerprint_model')
new_model.summary()
X_test_data = pd.read_csv('../data/DESC_data/external_test_set_new_extract_features.csv')
acc = new_model.predict(X_test_data, verbose=2)
for accuracy in acc:
    print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 2000)              3654000
# _________________________________________________________________
# dropout (Dropout)            (None, 2000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              2001000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               200200
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 5,855,401
# Trainable params: 5,855,401
# Non-trainable params: 0
# _________________________________________________________________
# 24/24 - 0s
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 48.39
# Accuracy: 49.62
# Accuracy: 48.33
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 65.37
# Accuracy: 49.62
# Accuracy: 47.82
# Accuracy: 32.12
# Accuracy: 42.35
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 53.22
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 53.33
# Accuracy: 49.62
# Accuracy: 51.43
# Accuracy: 42.31
# Accuracy: 53.25
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 47.55
# Accuracy: 45.34
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 50.88
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 52.02
# Accuracy: 49.62
# Accuracy: 49.15
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 47.86
# Accuracy: 49.62
# Accuracy: 34.06
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 53.60
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 58.28
# Accuracy: 47.79
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 57.82
# Accuracy: 50.24
# Accuracy: 49.62
# Accuracy: 47.64
# Accuracy: 49.56
# Accuracy: 47.13
# Accuracy: 19.66
# Accuracy: 49.62
# Accuracy: 53.16
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 44.76
# Accuracy: 52.78
# Accuracy: 49.62
# Accuracy: 48.97
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 59.44
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 51.89
# Accuracy: 52.22
# Accuracy: 49.62
# Accuracy: 55.03
# Accuracy: 53.77
# Accuracy: 46.53
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 46.93
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 71.06
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 44.20
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 45.22
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 51.33
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 48.68
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 46.37
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 38.40
# Accuracy: 49.57
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 48.69
# Accuracy: 49.33
# Accuracy: 54.68
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 57.66
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 56.21
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 68.76
# Accuracy: 57.31
# Accuracy: 49.62
# Accuracy: 41.81
# Accuracy: 49.62
# Accuracy: 50.20
# Accuracy: 100.00
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: 49.62
# Accuracy: